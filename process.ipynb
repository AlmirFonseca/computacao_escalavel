# %%
import subprocess as sp
import polars as pl
import altair as alt
import subprocess as sp
import sys

# %%
! g++ main.cpp -o main

# %%
for i in range(1, 101):
    output = sp.run(["./main.exe ", str(i)], capture_output=True)
    print(output)
# Out:
# CompletedProcess(args=['./main.exe ', '1'], returncode=3221225785, stdout=b'', stderr=b'')
# CompletedProcess(args=['./main.exe ', '2'], returncode=3221225785, stdout=b'', stderr=b'')
# CompletedProcess(args=['./main.exe ', '3'], returncode=3221225785, stdout=b'', stderr=b'')
# CompletedProcess(args=['./main.exe ', '4'], returncode=3221225785, stdout=b'', stderr=b'')
# CompletedProcess(args=['./main.exe ', '5'], returncode=3221225785, stdout=b'', stderr=b'')
# CompletedProcess(args=['./main.exe ', '6'], returncode=3221225785, stdout=b'', stderr=b'')
# CompletedProcess(args=['./main.exe ', '7'], returncode=3221225785, stdout=b'', stderr=b'')
# CompletedProcess(args=['./main.exe ', '8'], returncode=3221225785, stdout=b'', stderr=b'')
# CompletedProcess(args=['./main.exe ', '9'], returncode=3221225785, stdout=b'', stderr=b'')
# CompletedProcess(args=['./main.exe ', '10'], returncode=3221225785, stdout=b'', stderr=b'')
# ...
